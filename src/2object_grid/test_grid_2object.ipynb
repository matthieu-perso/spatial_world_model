# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/Othercomputers/我的 Mac mini/code/2object
# Out:
# /content/drive/Othercomputers/我的 Mac mini/code/2object

# %%
# !cp /content/drive/MyDrive/LLM_spatial_model_results/spatial_linear_probe.pt /content
# !cp /content/drive/MyDrive/LLM_spatial_model_results/spatial_activations.pt /content

# %%
# To load a pre-trained model and run tests
# !python main_grid.py --model_file /content/spatial_linear_probe.pt --activation_file /content/spatial_activations.pt --run_tests --test_comprehensive
# Out:
# Step 1: Loading saved activations from /content/spatial_activations.pt...
# Loading data from /content/spatial_activations.pt...
# Found 15000 sentences in saved data
# Analyzing distribution of spatial relations...
# Analyzing sentences for spatial relations: 100% 15000/15000 [00:00<00:00, 178912.44it/s]
# TOTAL ANALYSIS:
# Total sentences with valid relations: 15000
# Unique relations found: 18
#
# RELATION DISTRIBUTION BY CATEGORY:
# VERTICAL: 3000 (20.0%)
# HORIZONTAL: 3000 (20.0%)
# DEPTH: 3000 (20.0%)
# DIAGONAL: 3000 (20.0%)
# UNKNOWN: 3000 (20.0%)
#
# TOP 15 MOST COMMON RELATIONS:
# below: 1500 (10.0%) - vertical
# to the left of: 1500 (10.0%) - horizontal
# in front of: 1500 (10.0%) - depth
# above: 1500 (10.0%) - vertical
# behind: 1500 (10.0%) - depth
# to the right of: 1500 (10.0%) - horizontal
# diagonally back-left of: 750 (5.0%) - diagonal
# diagonally front-right of: 750 (5.0%) - diagonal
# diagonally front-left of: 750 (5.0%) - diagonal
# ...

# %%
# To run PCA analysis
# !python main_grid.py --model_file /content/spatial_linear_probe.pt --activation_file /content/spatial_activations.pt --run_pca
# Out:
# Step 1: Loading saved activations from /content/spatial_activations.pt...
# Loading data from /content/spatial_activations.pt...
# Found 15000 sentences in saved data
# Analyzing distribution of spatial relations...
# Analyzing sentences for spatial relations: 100% 15000/15000 [00:00<00:00, 179136.58it/s]
# TOTAL ANALYSIS:
# Total sentences with valid relations: 15000
# Unique relations found: 18
#
# RELATION DISTRIBUTION BY CATEGORY:
# VERTICAL: 3000 (20.0%)
# HORIZONTAL: 3000 (20.0%)
# DEPTH: 3000 (20.0%)
# DIAGONAL: 3000 (20.0%)
# UNKNOWN: 3000 (20.0%)
#
# TOP 15 MOST COMMON RELATIONS:
# below: 1500 (10.0%) - vertical
# to the left of: 1500 (10.0%) - horizontal
# in front of: 1500 (10.0%) - depth
# above: 1500 (10.0%) - vertical
# behind: 1500 (10.0%) - depth
# to the right of: 1500 (10.0%) - horizontal
# diagonally back-left of: 750 (5.0%) - diagonal
# diagonally front-right of: 750 (5.0%) - diagonal
# diagonally front-left of: 750 (5.0%) - diagonal
# ...

# %%
# To train a new model
# !python main_grid.py --extract_new --train_new --hf_token YOUR_TOKEN_HERE

# %%
# !python main_grid.py --extract_new --train_new
# Out:
# Step 1: Generating new training data...
#   Setting up language model: unsloth/Llama-3.2-3B
# 2025-04-18 21:55:31.406874: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-18 21:55:31.427021: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745013331.449169    3344 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
